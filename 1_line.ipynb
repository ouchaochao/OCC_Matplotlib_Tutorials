# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# linspace:-1到1， 50个点
x = np.linspace(-1, 1, 50)
y = 2 * x + 1
plt.plot(x, y)
plt.show()

# %%
# 坐标设置
x = np.linspace(-3, 3, 50)
y1 = 2 * x + 1
y2 = x ** 2

# figure1
plt.figure()
plt.plot(x, y1)

# figure2；figsize：长宽度
plt.figure(num=3, figsize=(8,5))
plt.plot(x, y2)
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--')

# 取值范围
plt.xlim((-1,2))
plt.ylim((-2,3))

# label坐标轴
plt.xlabel('X')
plt.ylabel('Y')

# tick变文字
new_tick = np.linspace(-1, 2, 5)
plt.xticks(new_tick)
plt.yticks([-2,-1.8,-1,1.22,3],
          ['$really \ bad$', '$bad \\alpha$', '$normal$', '$good$', '$really \ good$'])

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(x, y2)
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--')
plt.xlim((-1,2))
plt.ylim((-2,3))
plt.xlabel('X')
plt.ylabel('Y')
new_tick = np.linspace(-1, 2, 5)
plt.xticks(new_tick)
plt.yticks([-2,-1.8,-1,1.22,3],
          ['$really \ bad$', '$bad \\alpha$', '$normal$', '$good$', '$really \ good$'])

# 坐标轴移动 gca = 'get current axis'
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
                                 
plt.show()

# %%
# legend 图例
plt.figure(figsize=(8,5))
plt.plot(x, y2, label='blue')
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--', label='red')
plt.xlim((-1,2))
plt.ylim((-2,3))
plt.xlabel('X')
plt.ylabel('Y')
new_tick = np.linspace(-1, 2, 5)
plt.xticks(new_tick)
plt.yticks([-2,-1.8,-1,1.22,3],
          ['$really \ bad$', '$bad \\alpha$', '$normal$', '$good$', '$really \ good$'])
plt.legend(loc='best')
plt.show()

# %%
# annotation标注
plt.figure(figsize=(8,5),)
plt.plot(x, y1,)

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))

x0 = 1
y0 = 2 * x0 + 1
# scatter:点
plt.scatter(x0, y0, s=50, color='b')
plt.plot([x0, x0],[y0, 0], 'k--', lw=2.5)

# anntate
plt.annotate(r'$2x+1=%s$'%y0, xy=(x0, y0), xycoords='data', xytext=(+30, -30), textcoords='offset points',
            fontsize=16, arrowprops=dict(arrowstyle='->', connectionstyle='arc3, rad=.2'))
plt.show()

# %%
# tick能见度
y3 = 0.1*x

plt.figure()
plt.plot(x, y3, linewidth=10)
plt.ylim(-2, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))

for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='green', edgecolor='None', alpha=0.5))
plt.show()
